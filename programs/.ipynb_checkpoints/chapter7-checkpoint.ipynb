# %% [markdown]
# ## exp-1

# %% [markdown]
# 基于 MovieLens 100k 数据集中男性女性对电影的评分来判断男性还是女性电影评分的差异性更大。

# %%
import numpy as np
import pandas as pd

# %%
# 读入数据

unames = ['user id', 'age', 'gender', 'occupation', 'zip code']

users = pd.read_table('/Users/yanmk/学习/技术学习/Python/Python_NJU/resource/ml-100k/u.user', sep = '\|', names = unames, engine='python')

rnames = ['user id', 'item id', 'rating', 'timestamp']

ratings = pd.read_table('/Users/yanmk/学习/技术学习/Python/Python_NJU/resource/ml-100k/u.data', sep='\t', names = rnames, engine='python')

# %%
users
# Out:
#      user id  age gender     occupation zip code
# 0          1   24      M     technician    85711
# 1          2   53      F          other    94043
# 2          3   23      M         writer    32067
# 3          4   24      M     technician    43537
# 4          5   33      F          other    15213
# 5          6   42      M      executive    98101
# 6          7   57      M  administrator    91344
# 7          8   36      M  administrator    05201
# 8          9   29      M        student    01002
# 9         10   53      M         lawyer    90703
# 10        11   39      F          other    30329
# 11        12   28      F          other    06405
# 12        13   47      M       educator    29206
# 13        14   45      M      scientist    55106
# 14        15   49      F       educator    97301
# 15        16   21      M  entertainment    10309
# 16        17   30      M     programmer    06355
# 17        18   35      F          other    37212
# ...

# %%
ratings
# Out:
#        user id  item id  rating  timestamp
# 0          196      242       3  881250949
# 1          186      302       3  891717742
# 2           22      377       1  878887116
# 3          244       51       2  880606923
# 4          166      346       1  886397596
# 5          298      474       4  884182806
# 6          115      265       2  881171488
# 7          253      465       5  891628467
# 8          305      451       3  886324817
# 9            6       86       3  883603013
# 10          62      257       2  879372434
# 11         286     1014       5  879781125
# 12         200      222       5  876042340
# 13         210       40       3  891035994
# 14         224       29       3  888104457
# 15         303      785       3  879485318
# 16         122      387       5  879270459
# 17         194      274       2  879539794
# 18         291     1042       4  874834944
# 19         234     1184       2  892079237
# 20         119      392       4  886176814
# ...

# %%
# 选择需要的列，提高效率
users_df=pd.DataFrame()
ratings_df=pd.DataFrame()

users_df['user id']=users['user id']
users_df['gender']=users['gender']

ratings_df['user id']=ratings['user id']
ratings_df['rating']=ratings['rating']

# %%
# 合并数据
rating_df=pd.merge(users_df,ratings_df)

# %%
rating_df
# Out:
#        user id gender  rating
# 0            1      M       4
# 1            1      M       3
# 2            1      M       4
# 3            1      M       4
# 4            1      M       4
# 5            1      M       5
# 6            1      M       5
# 7            1      M       4
# 8            1      M       2
# 9            1      M       3
# 10           1      M       4
# 11           1      M       4
# 12           1      M       5
# 13           1      M       5
# 14           1      M       4
# 15           1      M       3
# 16           1      M       4
# 17           1      M       5
# 18           1      M       3
# 19           1      M       5
# 20           1      M       1
# 21           1      M       4
# 22           1      M       5
# 23           1      M       4
# 24           1      M       1
# 25           1      M       4
# 26           1      M       4
# 27           1      M       4
# 28           1      M       5
# 29           1      M       4
# ...

# %%
# 利用 pandas 中的数据透视表 pivot_table()函数对数据进行聚合
gender_table = pd.pivot_table(rating_df, index = ['gender', 'user id'], values = 'rating')

# %%
gender_table
# Out:
# gender  user id
# F       2          3.709677
#         5          2.874286
#         11         3.464088
#         12         4.392157
#         15         2.875000
#         18         3.880866
#         20         3.104167
#         23         3.635762
#         24         4.323529
#         27         3.240000
#         32         3.317073
#         34         4.050000
#         35         3.000000
#         36         3.800000
#         38         3.719008
#         43         3.710407
#         46         4.111111
#         49         2.683721
#         52         4.267857
#         62         3.301724
#         65         3.937500
#         72         3.817518
#         79         4.000000
#         80         3.758621
#         88         3.952381
#         89         4.039474
#         96         4.267857
#         98         3.592593
#         120        3.576923
#         122        3.983607
#                      ...
# M       898        3.500000
# ...

# %%
type(gender_table)
# Out:
# pandas.core.series.Series

# %%
gender_df = pd.DataFrame(gender_table)

# %%
gender_df
# Out:
#                   rating
# gender user id
# F      2        3.709677
#        5        2.874286
#        11       3.464088
#        12       4.392157
#        15       2.875000
#        18       3.880866
#        20       3.104167
#        23       3.635762
#        24       4.323529
#        27       3.240000
#        32       3.317073
#        34       4.050000
#        35       3.000000
#        36       3.800000
#        38       3.719008
#        43       3.710407
#        46       4.111111
#        49       2.683721
#        52       4.267857
#        62       3.301724
#        65       3.937500
#        72       3.817518
#        79       4.000000
#        80       3.758621
#        88       3.952381
#        89       4.039474
#        96       4.267857
#        98       3.592593
#        120      3.576923
#        122      3.983607
# ...                  ...
# M      898      3.500000
#        899      3.525926
#        900      2.555556
#        901      3.854839
# ...

# %%
Female_df = gender_df.query("gender == ['F']")

Male_df = gender_df.query("gender == ['M']")

# %%
Female_std = np.std(Female_df)

Male_std = np.std(Male_df)

print ('Gender', '\nF\t%.6f' % Female_std, '\nM\t%.6f' % Male_std)
# Out:
# Gender
# F	0.480358
# M	0.429755
